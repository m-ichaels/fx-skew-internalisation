# %% [markdown]
# # fx-skew-internalisation: results
# Loads `results/*.json` produced by `scripts/run_all.sh` and draws the README figures.

# %%
import json, os, sys
os.chdir('..')
sys.argv=['plots','results','results/figures']
exec(open('scripts/plots.py').read())
from IPython.display import Image, display
for f in ['quotes','skew_by_tier','frontier','decomposition','signatures','regime_sensitivity','lastlook']:
    display(Image(f'results/figures/{f}.png'))

# %% [markdown]
# ## Summary tables

# %%
print(open('results/summary.md').read())
